# %% [markdown]
# <a href="https://colab.research.google.com/github/thislis/2023_Big_Data_analysis/blob/main/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 사용된 데이터셋 : https://www.kaggle.com/datasets/whenamancodes/alcohol-effects-on-study

# %%
#구글 드라이브 마운트

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#필요 라이브러리 임포트

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#파일 로딩

df_math = pd.read_csv('/content/drive/MyDrive/빅데이터분석수행/술먹고 공부하기/studywithalcohol/Maths.csv')
df_portuguese = pd.read_csv('/content/drive/MyDrive/빅데이터분석수행/술먹고 공부하기/studywithalcohol/Portuguese.csv')

# %%
#필요한 자료 추출

df_math_alcohol = df_math[['Dalc', 'Walc']] #평일(Dalc)과 주말(Walc)의 알코올 소비 정도(1~5, 높을수록 많이 소비)
df_math_G3 = df_math['G3'] #G3 점수(1~20, 높을수록 성적 좋음)

df_portuguese_alcohol = df_portuguese[['Dalc', 'Walc']]
df_portuguese_G3 = df_portuguese['G3']

# %%
def just_avg(series):
  return (series[0] + series[1])/2 #단순 평균

def weight_avg(series):
  return series[0]*(5/7) + series[1]*(2/7) #가중 평균

# %%
#두 평균 계산 및 dataframe에 추가

m_ja_list = []
m_wa_list = []
p_ja_list = []
p_wa_list = []

for i in range(395):
  value = df_math_alcohol.loc[i]
  m_ja_list.append(just_avg(value))
  m_wa_list.append(weight_avg(value))

df_math_alcohol['weighted_avg'] = m_wa_list
df_math_alcohol['macro_avg'] = m_ja_list

for i in range(649):
  value = df_portuguese_alcohol.loc[i]
  p_ja_list.append(just_avg(value))
  p_wa_list.append(weight_avg(value))

df_portuguese_alcohol['weighted_avg'] = p_wa_list
df_portuguese_alcohol['macro_avg'] = p_ja_list

# %%
fig = plt.figure()
ax = fig.add_subplot()

x = df_math_alcohol['Dalc'].to_numpy()
y = df_math_G3

ax.set_xlabel('alcohol consumption\n(Dalc)')
ax.set_ylabel('G3 score')

scatter = ax.scatter(x, y, c='r', alpha=0.3, edgecolors='none')

plt.title("math-Dalc-G3")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()

x = df_math_alcohol['Walc'].to_numpy()
y = df_math_G3

ax.set_xlabel('alcohol consumption\n(Walc)')
ax.set_ylabel('G3 score')

scatter = ax.scatter(x, y, c='r', alpha=0.3, edgecolors='none')

plt.title("math-Walc-G3")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()

x = df_math_alcohol['macro_avg'].to_numpy()
y = df_math_G3

ax.set_xlabel('alcohol consumption\n(macro avg)')
ax.set_ylabel('G3 score')

scatter = ax.scatter(x, y, c='r', alpha=0.3, edgecolors='none')

plt.title("math-macro avg-G3")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()

x = df_math_alcohol['weighted_avg'].to_numpy()
y = df_math_G3

ax.set_xlabel('alcohol consumption\n(weighted avg)')
ax.set_ylabel('G3 score')

scatter = ax.scatter(x, y, c='r', alpha=0.3, edgecolors='none')

plt.title("math-weighted avg-G3")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()

x = df_portuguese_alcohol['Dalc'].to_numpy()
y = df_portuguese_G3

ax.set_xlabel('alcohol consumption\n(Dalc)')
ax.set_ylabel('G3 score')

scatter = ax.scatter(x, y, c='r', alpha=0.3, edgecolors='none')

plt.title("portuguese-Dalc-G3")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()

x = df_portuguese_alcohol['Walc'].to_numpy()
y = df_portuguese_G3

ax.set_xlabel('alcohol consumption\n(Walc)')
ax.set_ylabel('G3 score')

scatter = ax.scatter(x, y, c='r', alpha=0.3, edgecolors='none')

plt.title("portuguese-Walc-G3")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()

x = df_portuguese_alcohol['macro_avg'].to_numpy()
y = df_portuguese_G3

ax.set_xlabel('alcohol consumption\n(macro avg)')
ax.set_ylabel('G3 score')

scatter = ax.scatter(x, y, c='r', alpha=0.3, edgecolors='none')

plt.title("portuguese-macro avg-G3")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()

x = df_portuguese_alcohol['weighted_avg'].to_numpy()
y = df_portuguese_G3

ax.set_xlabel('alcohol consumption\n(weighted avg)')
ax.set_ylabel('G3 score')

scatter = ax.scatter(x, y, c='r', alpha=0.3, edgecolors='none')

plt.title("portuguese-weighted avg-G3")
plt.show()
